# %% [markdown]
# # Mouse clicker
#
# Make mouse interactions available on the notebook

# %%
import IPython
#help(IPython)

clicks = []

def js_click_handler(x, y, idx):
    clicks.append((x,y,idx))

# %%
print(clicks)
# Out:
# [(0.43103448275862066, 0.3024054982817869, 2), (0.49310344827586206, 0.4261168384879725, 2)]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from IPython.display import display, HTML
js = """<script>

</script>"""
display(HTML(js))

fig = plt.figure(figsize=(16,16))


A = np.diag([1,2,3,4,5])

ax = fig.add_subplot(221)
ax.matshow(A)

B = np.diag([-1,-2,-3,-4])

ay = fig.add_subplot(222)
ay.matshow(B)

az = fig.add_subplot(212)

","


C = np.array([[0,0,0,1], [1,0,0,0]])
az.matshow(C)
plt.show()
# Out:
# <script>
#
# </script>

# %%
fig = plt.figure(figsize=(8, 8))

A = np.diag([1,2,3,4,5])

ax = fig.add_subplot(111)
ax.matshow(A)

# %%
fig = plt.figure(figsize=(8, 8))

A = np.diag([1,2,3,4,5])

ax = fig.add_subplot(111)
ax.matshow(A)

# %%
fig = plt.figure(figsize=(8, 8))

A = np.diag([1,2,3,4,5])

ax = fig.add_subplot(111)
ax.matshow(A)
# Out:
# 99
