# %%
# %matplotlib inline
import helper
import matplotlib.pyplot as plt
import numpy as np
import cv2

I = cv2.imread('smila.jpg')
I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)
G = cv2.cvtColor(I, cv2.COLOR_RGB2GRAY)
plt.imshow(I)
plt.show()

# %%
R1 = helper.vectorize([I])
R2 = helper.vectorize([G])

X = helper.un_vectorize(R1, w=720, h=960)

X = X[0]
A = I - X

plt.imshow(A)
plt.show()
